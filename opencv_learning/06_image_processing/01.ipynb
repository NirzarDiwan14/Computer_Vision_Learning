# %%
import cv2 

image = cv2.imread("/home/nirzar-diwan/Desktop/computer_vision_learning/images/flower.jpg",cv2.IMREAD_GRAYSCALE)


if image is not None:
    image = cv2.resize(image,(600,600))
    cv2.imshow("This is sample image",image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Error: Image not found.")

# %%
edges  = cv2.Canny(
    image,
    threshold1=100,
    threshold2=200
)

bitwise_not = cv2.bitwise_not(edges)    
cv2.imshow("Original Image",image)
cv2.imshow("Edges",edges)
cv2.imshow("Bitwise Not",bitwise_not)
cv2.waitKey(0)      
cv2.destroyAllWindows()

# %%
# Bitwise operations 

"""
1- cv2.bitwise_and(img1, img2)
2- cv2.bitwise_or(img1, img2)
3- cv2.bitwise_not(img1)


* img1 img2 height width same
** use only black and white
*** 

"""
import cv2
import numpy as np

img1 = np.zeros((300,300), dtype="uint8")
img2 = np.zeros((300,300), dtype="uint8")

cv2.circle(img1, (150, 150), 100, 255, -1)

cv2.rectangle(img2, (100,100), (250,250), 255, -1)

bitwise_and = cv2.bitwise_and(img1, img2)
bitwise_or = cv2.bitwise_or(img1, img2)
bitwise_not = cv2.bitwise_not(img1)

cv2.imshow("Circle", img1)
cv2.imshow("Rectangle", img2)
cv2.imshow("AND", bitwise_and)
cv2.imshow("OR", bitwise_or)
cv2.imshow("NOT", bitwise_not)

cv2.waitKey(0)
cv2.destroyAllWindows()
