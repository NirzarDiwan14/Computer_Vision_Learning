# %%
import cv2 

image = cv2.imread("/home/nirzar-diwan/Desktop/computer_vision_learning/images/sample2.jpg")


if image is not None:
    image = cv2.resize(image,(600,600))
    # image = cv2.resize(image, None, fx=2, fy=2) 
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imshow("This is sample image",image)
    cv2.imshow("gray image",gray)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Error: Image not found.")


_, thresh = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

temp  = cv2.drawContours(
    temp,
    contours,
    -1,
    (0,255,0),
    5
)
# cv2.imshow("This is sample image",image)
cv2.imshow("gray image",gray)
cv2.imshow("temp image",temp)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 

image = cv2.imread("/home/nirzar-diwan/Desktop/computer_vision_learning/images/shapes_2.jpg")

if image is not None:
    image = cv2.resize(image, (600,600))

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    blur = cv2.GaussianBlur(gray, (5,5), 0)

    # 🔥 better edge detection
    thresh = cv2.Canny(blur, 30, 150)
    # _, thresh = cv2.threshold(gray, 60, 1000, cv2.THRESH_BINARY)

    contours, hierarchy = cv2.findContours(
        thresh, 
        cv2.RETR_EXTERNAL,
        cv2.CHAIN_APPROX_SIMPLE
    )
    ##-----
    for contour in contours:
        approx = cv2.approxPolyDP(contour,0.01 * cv2.arcLength(contour,True),True)
        corners = len(approx)
        if corners == 3:
            shape_name = "Triangle"
        elif corners == 4:
            shape_name = "Quadrilateral"
        elif corners ==5:          
            shape_name = "Pentagon"
        elif corners == 6:
            shape_name = "Hexagon"
        elif corners > 7:
            shape_name = "Circle"
        else:
            shape_name = "Unknown"
        cv2.drawContours(image,[approx],0,(0,255,0),3)
        x = approx.ravel()[0]
        y = approx.ravel()[1] - 10
        cv2.putText(image, shape_name, (x,y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)  

    ##-----

    temp = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

    cv2.drawContours(temp, contours, -1, (0,255,0), 3)

    cv2.imshow("Original", image)
    # cv2.imshow("Threshold", thresh)
    cv2.imshow("Contours", temp)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

else:
    print("Error: Image not found.")
